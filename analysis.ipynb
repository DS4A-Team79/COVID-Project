# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df=pd.read_csv("Datasets/Analytical.csv")

# %%
BANS = df.filter(["Bans per county"])
DEMOS = df.filter(["POPESTIMATE2019", 'PERC_MALE','PERC_FEMALE','PERC_WHITE','PERC_BLACK','PERC_NATIVE','PERC_ASIAN', 'PERC_PACIFIC'])
POP = df.filter(["POPESTIMATE2019"])

# %%
## Feature Engineering

df["Prop_infected"] = df["Total_cases"]/df['POPESTIMATE2019']
df["MaxNewCasesPerCap"] =df["Max_new_cases"]/df["POPESTIMATE2019"]

# %% [markdown]
# ### Funds per person

# %%
sns.scatterplot(x="Funds Per Person (2021)", y="Prop_infected", data=df)
# Out:
# <AxesSubplot:xlabel='Funds Per Person (2021)', ylabel='Prop_infected'>

# %%
sns.scatterplot(x="Funds Per Person (2021)", y="MaxNewCasesPerCap", data=df)
# Out:
# <AxesSubplot:xlabel='Funds Per Person (2021)', ylabel='MaxNewCasesPerCap'>

# %%
sns.scatterplot(x="Funds Per Person (2020)", y="Prop_infected", data=df)
# Out:
# <AxesSubplot:xlabel='Funds Per Person (2020)', ylabel='Prop_infected'>

# %%
sns.scatterplot(x="Funds Per Person (2021)", y="MaxNewCasesPerCap", data=df)
# Out:
# <AxesSubplot:xlabel='Funds Per Person (2021)', ylabel='MaxNewCasesPerCap'>

# %%
sns.scatterplot(x="Funds Per Person (2021)", y="MaxNewCasesPerCap", data=df)

# %%
sns.set_theme(style="ticks")

# %%
sns.pairplot(df).savefig("scatterplot_matrix.png")
